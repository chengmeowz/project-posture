# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Machine learning algorithms
from sklearn.linear_model import Ridge  # Ridge regression
from sklearn.kernel_ridge import KernelRidge  # Kernel ridge regression
from sklearn.ensemble import AdaBoostRegressor, RandomForestRegressor  # AdaBoost & Random Forest
from sklearn.neural_network import MLPRegressor  # Neural network
from sklearn.svm import SVR  # Support vector machine

# Cross-validation
from sklearn.model_selection import GridSearchCV, cross_val_score

# Evaluation
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import r2_score

class learning(object): 

    def __init__(self, alg, rule, file):        # alg = algorithm name, rule = evaluation rule
        self.alg = alg
        self.rule = rule
        self.file = file

    # Import dataset
    def loadDatasets(self):
        path = os.getcwd()#get current path
        path_up1Dir = os.path.dirname(path)#go up one directory
        dataset = pd.read_excel(path_up1Dir + self.file)#to import the preprocessed dataset into a variable

        X = pd.DataFrame(dataset.iloc[:,4:9])
        y = dataset['MVPA']
        other = pd.DataFrame(dataset.iloc[:,:4])
        
        return X, y, other, path_up1Dir

    # Which algorithm
    def algorithm(self):
        alg = self.alg
        
        if alg == 'ridge':
            model = Ridge()
        elif alg == 'kr':
            model = KernelRidge()
        elif alg == 'svr':
            model = SVR()
        elif alg == 'nn':
            model = MLPRegressor()
        elif alg == 'rf':
            model = RandomForestRegressor()
        elif alg == 'ab':
            model = AdaBoostRegressor()
        else:
            print("unvalid algorithm.")
            return 0
            
        return model
        
    # Set param_grid, aka the main parameters in dict
    def param_grid(self):
        alg = self.alg

        if alg == 'ridge':
            param_grid = [
                {'alpha':np.logspace(-6,6,13)},
                {'alpha':np.arange(1,1001,100)}
            ]

        elif alg == 'kr':
            param_grid = [
                {'kernel':['rbf'],
                 'gamma':np.logspace(-2,2,5),
                 'alpha':np.logspace(-6,6,13)
                },
                {'kernel':['linear'],
                 'alpha':np.logspace(-6,6,13)
                }
            ]

        elif alg == 'svr':
            param_grid = [
                {'kernel': ['linear'],
                 'C': np.logspace(0,3,4),
                 'coef0': np.linspace(0,5,10)
                 },
                {'kernel': ['rbf'],
                 'gamma': np.logspace(-10,1,20),
                 'C': np.logspace(0,3,4),
                 'coef0': np.linspace(0,5,10)
                 },
            ]

        elif alg == 'nn':
            # nhn_range = [1, 8, 10, 12, 14, 16, 18, 50]  # number of hidden neurons
            alpha = 10.0 ** -np.arange(1, 7)
            # for nhn in nhn_range:
            param_grid = {
                'alpha': alpha,
                'max_iter': [10000]
            }

               #  [
               # {'alpha': alpha,
               #  'hidden_layer_sizes': (np.arange(1, 52, 5),),
               #  'activation': ['identity', 'logistic', 'tanh', 'relu'],
               #  'solver': ['lbfgs'],
               #  'max_iter': [10000]
               #  },
               # {'alpha': alpha,
               #  'hidden_layer_sizes': (np.arange(1, 52, 5),),
               #  'activation': ['identity', 'logistic', 'tanh', 'relu'],
               #  'solver': ['adam', 'sgd']
               #  }
               #  ]

        elif alg == 'rf':
            param_grid = {
                'n_estimators':np.arange(10,101,10), # 从10到100，每隔10取一个
                'max_features':np.arange(0.1,1.1,0.1), # 从0.1到1，每隔0.1取一个
                'max_depth':np.arange(1,11),
                #'min_samples_split':np.arange(2,10),
                'bootstrap':[True,False]
            }

        elif alg == 'ab':
            param_grid = {
                'n_estimators':np.arange(10,201,10), # 从10到200，每隔10取一个
                'learning_rate':np.arange(0.1,1.1,0.1) # 从0.1到1，每隔0.1取一个
            }

        else:
            print("unvalid algorithm.")
            return 0

        return param_grid

        
    # GridSearchCV to find optimal parameters
    def gridSearchCV_eval(self):
        X = self.loadDatasets()[0]
        if (self.alg == 'ridge' or self.alg == 'kr'):
            y = self.loadDatasets()[1]
        else:
            y = self.loadDatasets()[1].values.ravel()
        
        grid = GridSearchCV(estimator=self.algorithm(), # algorithm
                            param_grid=self.param_grid(), # specify the parameters to search over using a dict
                            cv=10, # 10-Fold
                            scoring=self.rule # model evaluation rule
                            )

        # Build the model, aka training the dataset
        grid.fit(X, y)
        
        # Output the best parameter, cross-validation score, estimator, and the index of best estimator.
        print("\n------------------ %s Model" %self.algorithm())
        print("Best parameter: {}".format(grid.best_params_))
        print("Best score in %s: {:.2f}".format(grid.best_score_) %self.rule)
        #print("Average score in 10-Fold: \n", grid.cv_results_['mean_test_score'])
        #print("Std score in 10-Fold: \n", grid.cv_results_['std_test_score'])
        print("Best estimator: {}".format(grid.best_estimator_))
        #print("The Index of Best estimator: {}".format(grid.best_index_))
        
#         #######################
#         # Evaluation
#         yhat = grid.predict(X)
        
#         #print("Test set predictions:\n {}".format(yhat))
#         #score_MSE = MSE(y_true=y, y_pred=yhat)
        
#         print("\n------------------ Evaluation")
#         print("r2_score(yhat, y): \n", r2_score(yhat, y))
#         print("r2_score(y_true=y, y_pred=yhat): \n", r2_score(y_true=y, y_pred=yhat))

#         ave_score_cv = cross_val_score(grid, X, y, cv=10, scoring="r2").mean()
#         print("average r2 score in 10-Fold: ", ave_score_cv)

#         sorted(y)
#         plt.title("Linear Plot: %s Model w/ y_true & y_pred" %self.algorithm())
#         plt.plot(range(len(y)), sorted(y), c="black", label="Data")
#         plt.plot(range(len(yhat)), sorted(yhat), c="red", label="Predict")
#         plt.grid(True)
#         plt.legend()
#         plt.savefig(fname=self.loadDatasets()[3] + "/y_MVPA/linear_%s_y_true_VS_y_pred.png" %self.algorithm())
#         plt.show()
        
#         plt.title("Scatter Plot: %s Model w/ y_true & y_pred" %self.algorithm())
#         plt.scatter(x=y, y=yhat, alpha=0.25)
#         plt.xlabel('Actual') 
#         plt.ylabel('Predicted')
#         plt.grid(True)
#         plt.savefig(fname=self.loadDatasets()[3] + "/standardScaler/y_MVPA/scatter_%s_y_true_VS_y_pred.png" %self.algorithm())
#         plt.show()
        
#         return grid.best_estimator_, grid

    # 10-Fold cross-validation to check its accuracy
    def cross_val(self): 
        X = self.loadDatasets()[0]
        if (self.alg == 'ridge' or self.alg == 'kr'):
            y = self.loadDatasets()[1]
        else:
            y = self.loadDatasets()[1].values.ravel()
        
        score = cross_val_score(estimator=self.gridSearchCV()[0],
                            X=X, y=y,
                            cv=10,
                            scoring=self.rule
                           )
        print("\nBest score in %s:" %self.rule, score)
        
    # Use the above optimal parameters to build new model, aka training the dataset
    def fit(self):
        fit = self.gridSearchCV()[0].fit(self.loadDatasets()[0], self.loadDatasets()[1])

# %%
if __name__ == '__main__':
    models = ['ab'] # ['ridge', 'kr', 'svr', 'nn', 'rf', 'ab']
    rules = ['neg_mean_absolute_error', 'neg_mean_squared_error', 'r2'] # ['neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_median_absolute_error', 'r2']

    for model in models:
        for rule in rules:
            test = learning(model, rule, '/standardScaler/standardScaler.xlsx')
            test.gridSearchCV_eval()
# Out:
# ------------------ Ridge() Model
# Best parameter: {'alpha': 1000.0}
# Best score in neg_mean_absolute_error: -0.64
# Best estimator: Ridge(alpha=1000.0)
#
# ------------------ Ridge() Model
# Best parameter: {'alpha': 100000.0}
# Best score in neg_mean_squared_error: -1.02
# Best estimator: Ridge(alpha=100000.0)
#
# ------------------ Ridge() Model
# Best parameter: {'alpha': 10000.0}
# Best score in r2: -0.19
# Best estimator: Ridge(alpha=10000.0)
#
# ------------------ KernelRidge() Model
# Best parameter: {'alpha': 100.0, 'gamma': 1.0, 'kernel': 'rbf'}
# Best score in neg_mean_absolute_error: -0.63
# Best estimator: KernelRidge(alpha=100.0, gamma=1.0, kernel='rbf')
#
# ------------------ KernelRidge() Model
# Best parameter: {'alpha': 10.0, 'gamma': 100.0, 'kernel': 'rbf'}
# Best score in neg_mean_squared_error: -1.00
# Best estimator: KernelRidge(alpha=10.0, gamma=100.0, kernel='rbf')
#
# ------------------ KernelRidge() Model
# Best parameter: {'alpha': 100.0, 'gamma': 10.0, 'kernel': 'rbf'}
# Best score in r2: -0.15
# Best estimator: KernelRidge(alpha=100.0, gamma=10.0, kernel='rbf')
#
# ------------------ SVR() Model
# Best parameter: {'C': 1000.0, 'coef0': 0.0, 'gamma': 7.847599703514623e-08, 'kernel': 'rbf'}
# Best score in neg_mean_absolute_error: -0.57
# Best estimator: SVR(C=1000.0, gamma=7.847599703514623e-08)
#
# ------------------ SVR() Model
# Best parameter: {'C': 1.0, 'coef0': 0.0, 'gamma': 10.0, 'kernel': 'rbf'}
# Best score in neg_mean_squared_error: -1.08
# Best estimator: SVR(gamma=10.0)
#
# ------------------ SVR() Model
# Best parameter: {'C': 1000.0, 'coef0': 0.0, 'gamma': 7.847599703514623e-08, 'kernel': 'rbf'}
# Best score in r2: -0.16
# Best estimator: SVR(C=1000.0, gamma=7.847599703514623e-08)
#
# ------------------ MLPRegressor() Model
# Best parameter: {'alpha': 0.1, 'max_iter': 10000}
# Best score in neg_mean_absolute_error: -0.66
# Best estimator: MLPRegressor(alpha=0.1, max_iter=10000)
#
# ------------------ MLPRegressor() Model
# Best parameter: {'alpha': 0.1, 'max_iter': 10000}
# Best score in neg_mean_squared_error: -1.12
# Best estimator: MLPRegressor(alpha=0.1, max_iter=10000)
#
# ------------------ MLPRegressor() Model
# Best parameter: {'alpha': 1e-05, 'max_iter': 10000}
# Best score in r2: -0.39
# Best estimator: MLPRegressor(alpha=1e-05, max_iter=10000)
#
# ------------------ RandomForestRegressor() Model
# Best parameter: {'bootstrap': True, 'max_depth': 1, 'max_features': 0.7000000000000001, 'n_estimators': 10}
# Best score in neg_mean_absolute_error: -0.64
# Best estimator: RandomForestRegressor(max_depth=1, max_features=0.7000000000000001,
#                       n_estimators=10)
#
# ------------------ RandomForestRegressor() Model
# Best parameter: {'bootstrap': True, 'max_depth': 1, 'max_features': 0.5, 'n_estimators': 30}
# Best score in neg_mean_squared_error: -1.02
# Best estimator: RandomForestRegressor(max_depth=1, max_features=0.5, n_estimators=30)
#
# ------------------ RandomForestRegressor() Model
# Best parameter: {'bootstrap': True, 'max_depth': 1, 'max_features': 0.30000000000000004, 'n_estimators': 20}
# Best score in r2: -0.18
# Best estimator: RandomForestRegressor(max_depth=1, max_features=0.30000000000000004,
#                       n_estimators=20)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-3387f1c24f38> in <module>
#       6         for rule in rules:
#       7             test = learning(model, rule, '/y_MVPA/y_MVPA.xlsx')
# ----> 8             test.gridSearchCV_eval()
#
# <ipython-input-7-2cd96e7081c1> in gridSearchCV_eval(self)
#     140     # GridSearchCV to find optimal parameters
#     141     def gridSearchCV_eval(self):
# --> 142         X = self.loadDatasets()[0]
#     143         if (self.alg == 'ridge' or self.alg == 'kr'):
#     144             y = self.loadDatasets()[1]
#
# <ipython-input-7-2cd96e7081c1> in loadDatasets(self)
#      29         path = os.getcwd()#get current path
#      30         path_up1Dir = os.path.dirname(path)#go up one directory
# ---> 31         dataset = pd.read_excel(path_up1Dir + self.file)#to import the preprocessed dataset into a variable
#      32
#      33         X = pd.DataFrame(dataset.iloc[:,4:9])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
#     335         should_close = True
# --> 336         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     337     elif engine and engine != io.engine:
#     338         raise ValueError(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1069                 ext = "xls"
#    1070             else:
# -> 1071                 ext = inspect_excel_format(
#    1072                     content=path_or_buffer, storage_options=storage_options
#    1073                 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in inspect_excel_format(path, content, storage_options)
#     947     assert content_or_path is not None
#     948
# --> 949     with get_handle(
#     950         content_or_path, "rb", storage_options=storage_options, is_text=False
#     951     ) as handle:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     649         else:
#     650             # Binary mode
# --> 651             handle = open(handle, ioargs.mode)
#     652         handles.append(handle)
#     653
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/zclalala/Documents/GitHub/project-posture/y_MVPA/y_MVPA.xlsx'
